# %% [markdown]
# # Problem 2 [50 points]
#
# In this question, you will develop a Convolutional Neural Network (CNN) to classify polygons ranging from quadrilaterals to octagons. The provided dataset, `polygon_dataset.npz`, is in a simple NumPy `.npz` format and can be accessed at [DATA621 GitHub/Assignments/02](https://github.com/cfteach/NNDL_DATA621/tree/webpage-src/DATA621/DATA621/Assignments/02). A sample code snippet is provided in the template to quickly read the dataset but you can build your own code.
#
#
# The polygonal shapes have been scaled and rotated, and your task is to classify them into the correct polygon type.

# %%
! wget https://github.com/cfteach/NNDL_DATA621/raw/refs/heads/webpage-src/DATA621/DATA621/Assignments/02/polygon_dataset.npz
! pip install matplotlib torch numpy torchvision

# %%
# Function to  display the training sample
import numpy as np


data = np.load("polygon_dataset.npz")
images = data['images']
labels = data['labels']

# Verify the data
print(images.shape)  # (1400, 100, 100) for 1400 images of size 100x100
print(labels.shape)  # (1400,) for 1600 labels
# Out:
# (30000, 50, 50)
# (30000,)

# %%
# display the few images with labels

def display_images(image, label):
    plt.figure(figsize=(10, 10))
    for i in range(25):
        plt.subplot(5, 5, i + 1)
        plt.xticks([])
        plt.yticks([])
        plt.grid(False)
        plt.imshow(image[i], cmap="gray")
        plt.xlabel(label[i])
    plt.show()

display_images(images, labels)

# %% [markdown]
# ## P.2.1 P.2.1: CNN Classification of Polygon Shapes (40 points)

# %%
class PolygonClassifier(nn.Module):
    def __init__(self):
        super(PolygonClassifier, self).__init__()
        pass

    def forward(self, x):
        pass

# %%
# Define a loss function and an optimizer
criterion = None
optimizer = None
# Train the model
def train_model(**kwargs):
    history = {
        "loss": [],
        "accuracy": [],
        "val_loss": [],
        "val_accuracy": []
    }

    for epoch in range(n_epochs):
        pass
        print(f"Epoch {epoch + 1:2d}/{n_epochs} - "
              f"Training Loss: {history['loss'][-1]:.4f}, "
              f"Training Accuracy: {history['accuracy'][-1]:.4f}, "
              f"Validation Loss: {history['val_loss'][-1]:.4f}, "
              f"Validation Accuracy: {history['val_accuracy'][-1]:.4f}"
              )

    return history

# %% [markdown]
# ## P.2.2 CNN Testing (10 points)
#
# 1. Evaluate the model on the testing datasets.
#
# 2. Create a confusion matrix for the test dataset to show how well your model classified each polygon.
#
# 3. Report the accuracy for each class separately (i.e., per-class accuracy) and ensure that no class is significantly underrepresented in the evaluation metrics. Consider using metrics like precision, recall, or F1-score to better assess performance on each class.
#
# 4. Describe any challenges you faced in reaching 80\% accuracy and how you addressed them.
