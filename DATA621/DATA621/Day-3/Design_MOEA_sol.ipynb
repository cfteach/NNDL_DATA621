# %% [markdown]
# ## MOEA

# %%
# !wget https://raw.githubusercontent.com/cfteach/modules/master/detector2.py
# !pip install pymoo
# !pip install plotly
# !pip install ipyvolume
# !pip install altair
# Out:
# --2024-07-10 06:27:57--  https://raw.githubusercontent.com/cfteach/modules/master/detector2.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.110.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 7976 (7.8K) [text/plain]
# Saving to: ‘detector2.py.1’
#
# detector2.py.1      100%[===================>]   7.79K  --.-KB/s    in 0.02s
#
# 2024-07-10 06:27:57 (485 KB/s) - ‘detector2.py.1’ saved [7976/7976]
#
# Collecting pymoo
#   Using cached pymoo-0.6.1.1-py3-none-any.whl
# Requirement already satisfied: numpy>=1.15 in /home/ksuresh/miniconda3/envs/env_AID2E/lib/python3.12/site-packages (from pymoo) (1.26.0)
# Requirement already satisfied: scipy>=1.1 in /home/ksuresh/miniconda3/envs/env_AID2E/lib/python3.12/site-packages (from pymoo) (1.13.0)
# Requirement already satisfied: matplotlib>=3 in /home/ksuresh/miniconda3/envs/env_AID2E/lib/python3.12/site-packages (from pymoo) (3.9.0)
# Collecting autograd>=1.4 (from pymoo)
#   Using cached autograd-1.6.2-py3-none-any.whl.metadata (706 bytes)
# Collecting cma==3.2.2 (from pymoo)
#   Using cached cma-3.2.2-py2.py3-none-any.whl.metadata (8.0 kB)
# Collecting alive-progress (from pymoo)
#   Using cached alive_progress-3.1.5-py3-none-any.whl.metadata (68 kB)
# Collecting dill (from pymoo)
#   Using cached dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Collecting Deprecated (from pymoo)
#   Using cached Deprecated-1.2.14-py2.py3-none-any.whl.metadata (5.4 kB)
# Collecting future>=0.15.2 (from autograd>=1.4->pymoo)
#   Using cached future-1.0.0-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /home/ksuresh/miniconda3/envs/env_AID2E/lib/python3.12/site-packages (from matplotlib>=3->pymoo) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /home/ksuresh/miniconda3/envs/env_AID2E/lib/python3.12/site-packages (from matplotlib>=3->pymoo) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/ksuresh/miniconda3/envs/env_AID2E/lib/python3.12/site-packages (from matplotlib>=3->pymoo) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/ksuresh/miniconda3/envs/env_AID2E/lib/python3.12/site-packages (from matplotlib>=3->pymoo) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /home/ksuresh/miniconda3/envs/env_AID2E/lib/python3.12/site-packages (from matplotlib>=3->pymoo) (24.0)
# Requirement already satisfied: pillow>=8 in /home/ksuresh/miniconda3/envs/env_AID2E/lib/python3.12/site-packages (from matplotlib>=3->pymoo) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/ksuresh/miniconda3/envs/env_AID2E/lib/python3.12/site-packages (from matplotlib>=3->pymoo) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/ksuresh/miniconda3/envs/env_AID2E/lib/python3.12/site-packages (from matplotlib>=3->pymoo) (2.9.0)
# Collecting about-time==4.2.1 (from alive-progress->pymoo)
#   Using cached about_time-4.2.1-py3-none-any.whl.metadata (13 kB)
# Collecting grapheme==0.6.0 (from alive-progress->pymoo)
#   Using cached grapheme-0.6.0-py3-none-any.whl
# Collecting wrapt<2,>=1.10 (from Deprecated->pymoo)
#   Using cached wrapt-1.16.0-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: six>=1.5 in /home/ksuresh/miniconda3/envs/env_AID2E/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib>=3->pymoo) (1.16.0)
# Using cached cma-3.2.2-py2.py3-none-any.whl (249 kB)
# Using cached autograd-1.6.2-py3-none-any.whl (49 kB)
# Using cached alive_progress-3.1.5-py3-none-any.whl (75 kB)
# Using cached about_time-4.2.1-py3-none-any.whl (13 kB)
# Using cached Deprecated-1.2.14-py2.py3-none-any.whl (9.6 kB)
# Using cached dill-0.3.8-py3-none-any.whl (116 kB)
# Using cached future-1.0.0-py3-none-any.whl (491 kB)
# Using cached wrapt-1.16.0-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (87 kB)
# Installing collected packages: grapheme, wrapt, future, dill, cma, about-time, Deprecated, autograd, alive-progress, pymoo
# Successfully installed Deprecated-1.2.14 about-time-4.2.1 alive-progress-3.1.5 autograd-1.6.2 cma-3.2.2 dill-0.3.8 future-1.0.0 grapheme-0.6.0 pymoo-0.6.1.1 wrapt-1.16.0
# Requirement already satisfied: plotly in /home/ksuresh/miniconda3/envs/env_AID2E/lib/python3.12/site-packages (5.22.0)
# Requirement already satisfied: tenacity>=6.2.0 in /home/ksuresh/miniconda3/envs/env_AID2E/lib/python3.12/site-packages (from plotly) (8.3.0)
# Requirement already satisfied: packaging in /home/ksuresh/miniconda3/envs/env_AID2E/lib/python3.12/site-packages (from plotly) (24.0)
# Requirement already satisfied: ipyvolume in /home/ksuresh/miniconda3/envs/env_AID2E/lib/python3.12/site-packages (0.6.3)
# Requirement already satisfied: ipywidgets>=7.0.0 in /home/ksuresh/miniconda3/envs/env_AID2E/lib/python3.12/site-packages (from ipyvolume) (8.1.3)
# Requirement already satisfied: bqplot in /home/ksuresh/miniconda3/envs/env_AID2E/lib/python3.12/site-packages (from ipyvolume) (0.12.43)
# Requirement already satisfied: numpy in /home/ksuresh/miniconda3/envs/env_AID2E/lib/python3.12/site-packages (from ipyvolume) (1.26.0)
# Requirement already satisfied: traittypes in /home/ksuresh/miniconda3/envs/env_AID2E/lib/python3.12/site-packages (from ipyvolume) (0.2.1)
# Requirement already satisfied: traitlets in /home/ksuresh/miniconda3/envs/env_AID2E/lib/python3.12/site-packages (from ipyvolume) (5.14.3)
# Requirement already satisfied: Pillow in /home/ksuresh/miniconda3/envs/env_AID2E/lib/python3.12/site-packages (from ipyvolume) (10.3.0)
# Requirement already satisfied: ipywebrtc in /home/ksuresh/miniconda3/envs/env_AID2E/lib/python3.12/site-packages (from ipyvolume) (0.6.0)
# Requirement already satisfied: requests in /home/ksuresh/miniconda3/envs/env_AID2E/lib/python3.12/site-packages (from ipyvolume) (2.32.3)
# Requirement already satisfied: ipyvuetify in /home/ksuresh/miniconda3/envs/env_AID2E/lib/python3.12/site-packages (from ipyvolume) (1.9.4)
# Requirement already satisfied: ipyvue>=1.7.0 in /home/ksuresh/miniconda3/envs/env_AID2E/lib/python3.12/site-packages (from ipyvolume) (1.11.1)
# Requirement already satisfied: pythreejs>=2.4.0 in /home/ksuresh/miniconda3/envs/env_AID2E/lib/python3.12/site-packages (from ipyvolume) (2.4.2)
# Requirement already satisfied: matplotlib in /home/ksuresh/miniconda3/envs/env_AID2E/lib/python3.12/site-packages (from ipyvolume) (3.9.0)
# Requirement already satisfied: comm>=0.1.3 in /home/ksuresh/miniconda3/envs/env_AID2E/lib/python3.12/site-packages (from ipywidgets>=7.0.0->ipyvolume) (0.2.2)
# Requirement already satisfied: ipython>=6.1.0 in /home/ksuresh/miniconda3/envs/env_AID2E/lib/python3.12/site-packages (from ipywidgets>=7.0.0->ipyvolume) (8.24.0)
# Requirement already satisfied: widgetsnbextension~=4.0.11 in /home/ksuresh/miniconda3/envs/env_AID2E/lib/python3.12/site-packages (from ipywidgets>=7.0.0->ipyvolume) (4.0.11)
# Requirement already satisfied: jupyterlab-widgets~=3.0.11 in /home/ksuresh/miniconda3/envs/env_AID2E/lib/python3.12/site-packages (from ipywidgets>=7.0.0->ipyvolume) (3.0.11)
# Requirement already satisfied: ipydatawidgets>=1.1.1 in /home/ksuresh/miniconda3/envs/env_AID2E/lib/python3.12/site-packages (from pythreejs>=2.4.0->ipyvolume) (4.3.5)
# Requirement already satisfied: pandas<3.0.0,>=1.0.0 in /home/ksuresh/miniconda3/envs/env_AID2E/lib/python3.12/site-packages (from bqplot->ipyvolume) (2.2.2)
# Requirement already satisfied: contourpy>=1.0.1 in /home/ksuresh/miniconda3/envs/env_AID2E/lib/python3.12/site-packages (from matplotlib->ipyvolume) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /home/ksuresh/miniconda3/envs/env_AID2E/lib/python3.12/site-packages (from matplotlib->ipyvolume) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/ksuresh/miniconda3/envs/env_AID2E/lib/python3.12/site-packages (from matplotlib->ipyvolume) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/ksuresh/miniconda3/envs/env_AID2E/lib/python3.12/site-packages (from matplotlib->ipyvolume) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /home/ksuresh/miniconda3/envs/env_AID2E/lib/python3.12/site-packages (from matplotlib->ipyvolume) (24.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/ksuresh/miniconda3/envs/env_AID2E/lib/python3.12/site-packages (from matplotlib->ipyvolume) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/ksuresh/miniconda3/envs/env_AID2E/lib/python3.12/site-packages (from matplotlib->ipyvolume) (2.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/ksuresh/miniconda3/envs/env_AID2E/lib/python3.12/site-packages (from requests->ipyvolume) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/ksuresh/miniconda3/envs/env_AID2E/lib/python3.12/site-packages (from requests->ipyvolume) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/ksuresh/miniconda3/envs/env_AID2E/lib/python3.12/site-packages (from requests->ipyvolume) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ksuresh/miniconda3/envs/env_AID2E/lib/python3.12/site-packages (from requests->ipyvolume) (2024.2.2)
# Requirement already satisfied: decorator in /home/ksuresh/miniconda3/envs/env_AID2E/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->ipyvolume) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /home/ksuresh/miniconda3/envs/env_AID2E/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->ipyvolume) (0.19.1)
# Requirement already satisfied: matplotlib-inline in /home/ksuresh/miniconda3/envs/env_AID2E/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->ipyvolume) (0.1.7)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /home/ksuresh/miniconda3/envs/env_AID2E/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->ipyvolume) (3.0.42)
# Requirement already satisfied: pygments>=2.4.0 in /home/ksuresh/miniconda3/envs/env_AID2E/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->ipyvolume) (2.18.0)
# Requirement already satisfied: stack-data in /home/ksuresh/miniconda3/envs/env_AID2E/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->ipyvolume) (0.6.2)
# Requirement already satisfied: pexpect>4.3 in /home/ksuresh/miniconda3/envs/env_AID2E/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->ipyvolume) (4.9.0)
# Requirement already satisfied: pytz>=2020.1 in /home/ksuresh/miniconda3/envs/env_AID2E/lib/python3.12/site-packages (from pandas<3.0.0,>=1.0.0->bqplot->ipyvolume) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/ksuresh/miniconda3/envs/env_AID2E/lib/python3.12/site-packages (from pandas<3.0.0,>=1.0.0->bqplot->ipyvolume) (2024.1)
# Requirement already satisfied: six>=1.5 in /home/ksuresh/miniconda3/envs/env_AID2E/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib->ipyvolume) (1.16.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /home/ksuresh/miniconda3/envs/env_AID2E/lib/python3.12/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets>=7.0.0->ipyvolume) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /home/ksuresh/miniconda3/envs/env_AID2E/lib/python3.12/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets>=7.0.0->ipyvolume) (0.7.0)
# Requirement already satisfied: wcwidth in /home/ksuresh/miniconda3/envs/env_AID2E/lib/python3.12/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets>=7.0.0->ipyvolume) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in /home/ksuresh/miniconda3/envs/env_AID2E/lib/python3.12/site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=7.0.0->ipyvolume) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in /home/ksuresh/miniconda3/envs/env_AID2E/lib/python3.12/site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=7.0.0->ipyvolume) (2.4.1)
# Requirement already satisfied: pure-eval in /home/ksuresh/miniconda3/envs/env_AID2E/lib/python3.12/site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=7.0.0->ipyvolume) (0.2.2)
# Collecting altair
#   Using cached altair-5.3.0-py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: jinja2 in /home/ksuresh/miniconda3/envs/env_AID2E/lib/python3.12/site-packages (from altair) (3.1.4)
# Requirement already satisfied: jsonschema>=3.0 in /home/ksuresh/miniconda3/envs/env_AID2E/lib/python3.12/site-packages (from altair) (4.22.0)
# Requirement already satisfied: numpy in /home/ksuresh/miniconda3/envs/env_AID2E/lib/python3.12/site-packages (from altair) (1.26.0)
# Requirement already satisfied: packaging in /home/ksuresh/miniconda3/envs/env_AID2E/lib/python3.12/site-packages (from altair) (24.0)
# Requirement already satisfied: pandas>=0.25 in /home/ksuresh/miniconda3/envs/env_AID2E/lib/python3.12/site-packages (from altair) (2.2.2)
# Collecting toolz (from altair)
#   Using cached toolz-0.12.1-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: attrs>=22.2.0 in /home/ksuresh/miniconda3/envs/env_AID2E/lib/python3.12/site-packages (from jsonschema>=3.0->altair) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/ksuresh/miniconda3/envs/env_AID2E/lib/python3.12/site-packages (from jsonschema>=3.0->altair) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/ksuresh/miniconda3/envs/env_AID2E/lib/python3.12/site-packages (from jsonschema>=3.0->altair) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/ksuresh/miniconda3/envs/env_AID2E/lib/python3.12/site-packages (from jsonschema>=3.0->altair) (0.18.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/ksuresh/miniconda3/envs/env_AID2E/lib/python3.12/site-packages (from pandas>=0.25->altair) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in /home/ksuresh/miniconda3/envs/env_AID2E/lib/python3.12/site-packages (from pandas>=0.25->altair) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/ksuresh/miniconda3/envs/env_AID2E/lib/python3.12/site-packages (from pandas>=0.25->altair) (2024.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/ksuresh/miniconda3/envs/env_AID2E/lib/python3.12/site-packages (from jinja2->altair) (2.1.5)
# Requirement already satisfied: six>=1.5 in /home/ksuresh/miniconda3/envs/env_AID2E/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas>=0.25->altair) (1.16.0)
# Using cached altair-5.3.0-py3-none-any.whl (857 kB)
# Using cached toolz-0.12.1-py3-none-any.whl (56 kB)
# Installing collected packages: toolz, altair
# Successfully installed altair-5.3.0 toolz-0.12.1

# %%
# %load_ext autoreload
# %autoreload 2


import os
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
#import AI4NP_detector_opt.sol2.detector2 as detector2
import detector2
from pymoo.algorithms.moo.nsga2 import NSGA2
from pymoo.core.problem import Problem
from pymoo.optimize import minimize
from pymoo.visualization.scatter import Scatter
from pymoo.util.display.column import Column
from pymoo.util.display.output import Output

from pymoo.util.nds.non_dominated_sorting import NonDominatedSorting
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ### Create detector geometry and simulate tracks
#
# The module detector creates a simple 2D geometry of a wire based tracker made by 4 planes.
#
# The adjustable parameters are the radius of each wire, the pitch (along the y axis), and the shift along y and z of a plane with respect to the previous one.
#
# A total of 8 parameters can be tuned.
#
# The goal of this toy model, is to tune the detector design so to optimize the efficiency (fraction of tracks which are detected) as well as the cost for its realization. As a proxy for the cost, we use the material/volume (the surface in 2D) of the detector. For a track to be detetected, in the efficiency definition we require at least two wires hit by the track.
#
# So we want to maximize the efficiency (defined in detector.py) and minimize the cost.
#
# #### LIST OF PARAMETERS
# (baseline values)
# * R = .5   [cm]
# * pitch = 4.0  [cm]
# * y1 = 0.0, y2 = 0.0, y3 = 0.0, z1 = 2.0, z2 = 4.0, z3 = 6.0 [cm]

# %%
# CONSTANT PARAMETERS
#------ define mother region ------#
y_min=-10.1
y_max=10.1
N_tracks = 1000


print("::::: BASELINE PARAMETERS :::::")
R = 0.5
pitch = 4.0
y1 = 2.0
y2 = 1.0
y3 = 0.0
z1 = 2.0
z2 = 4.0
z3 = 6.0

print("R, pitch, y1, y2, y3, z1, z2, z3: ", R, pitch, y1, y2, y3, z1, z2, z3,"\n")


#------------- GEOMETRY ---------------#
print(":::: INITIAL GEOMETRY ::::")
tr = detector2.Tracker(R, pitch, y1, y2, y3, z1, z2, z3)
Z, Y = tr.create_geometry()
num_wires = detector2.calculate_wires(Y, y_min, y_max)

volume = detector2.wires_volume(Y, y_min, y_max,R)

detector2.geometry_display(Z, Y, R, y_min=y_min, y_max=y_max,block=False,pause=5) #5

print("# of wires: ", num_wires, ", volume: ", volume)

#------------- TRACK GENERATION -----------#
print(":::: TRACK GENERATION ::::")
t = detector2.Tracks(b_min=y_min, b_max=y_max, alpha_mean=0, alpha_std=0.2)
tracks = t.generate(N_tracks)

detector2.geometry_display(Z, Y, R, y_min=y_min, y_max=y_max,block=False, pause=-1)
detector2.tracks_display(tracks, Z,block=False,pause=-1)

 #a track is detected if at least two wires have been hit
score = detector2.get_score(Z, Y, tracks, R)
frac_detected = score[0]
resolution = score[1]
print("fraction of tracks detected: ",frac_detected)
print("resolution: ",resolution)
# Out:
# ::::: BASELINE PARAMETERS :::::
# R, pitch, y1, y2, y3, z1, z2, z3:  0.5 4.0 2.0 1.0 0.0 2.0 4.0 6.0
#
# :::: INITIAL GEOMETRY ::::
# # of wires:  21 , volume:  65.94
# :::: TRACK GENERATION ::::
# fraction of tracks detected:  0.243
# resolution:  0.23594329069824552

# %% [markdown]
# ---
#
# ### Define Objectives
#
#
#
# Defines a class for the objectives of the problem that can be used in the MOO.

# %%
class objectives():

  def __init__(self,tracks,y_min,y_max):
    self.tracks = tracks
    self.y_min = y_min
    self.y_max = y_max

  def wrapper_geometry(fun):

      def inner(self):
          R, pitch, y1, y2, y3, z1, z2, z3 = self.X
          self.geometry(R, pitch, y1, y2, y3, z1, z2, z3)
          return fun(self)
      return inner

  def update_tracks(self, new_tracks):
    self.tracks = new_tracks

  def update_design_point(self,X):
      self.X = X


  def geometry(self,R, pitch, y1, y2, y3, z1, z2, z3):
    tr = detector2.Tracker(R, pitch, y1, y2, y3, z1, z2, z3)
    self.R = R
    self.Z, self.Y = tr.create_geometry()


  @wrapper_geometry
  def calc_score(self):
      res = detector2.get_score(self.Z, self.Y, self.tracks, self.R)
      assert res[0] >= 0 and res[1] >= 0,"Fraction or Resolution negative."

      return res


  def get_score(self,X):
    R, pitch, y1, y2, y3, z1, z2, z3 = X
    self.geometry(R, pitch, y1, y2, y3, z1, z2, z3)
    res = detector2.get_score(self.Z, self.Y, self.tracks, self.R)
    return res


  def get_volume(self):
    volume = detector2.wires_volume(self.Y, self.y_min, self.y_max,self.R)
    return volume



res = objectives(tracks,y_min,y_max)

#res.geometry(R, pitch, y1, y2, y3, z1, z2, z3)

X = R, pitch, y1, y2, y3, z1, z2, z3
#fscore  = res.get_score(X)
res.update_design_point(X)
fscore  = res.calc_score()[0]
fvolume = res.get_volume()

print("...check: ", fvolume, fscore)
# Out:
# ...check:  65.94 0.243

# %% [markdown]
# ---
# ### Multi-Objective Optimization
#
# We will be using pymoo (https://pymoo.org/getting_started.html).
#
# * In the constructor method we specify number of variables N, objectives M, and constraint functions, as well as the lower and upper boundaries of each variable. In our toy model, these boundaries are taken in such a way that all solutions are feasible and no constraint function is needed. You can try to change this and introduce some constraint.
#
#
#
# * The *_evaluate* method takes a one-dimensional NumPy array x number of entries equal to n_var. This behavior is enabled by setting *elementwise_evaluation=True* while calling the super() method.
#
# * Notice that every function is minimized. Our efficiency is defined as an tracking inefficiency = 1 - efficiency
#
# * We add the resolution as a third objective.  The average residual of the track hit from the wire centre is used as a proxy for the resolution for this toy-model

# %%
from pymoo.core.problem import ElementwiseProblem
class MyProblem(ElementwiseProblem):

    #--------- vectorized ---------#

    def __init__(self):
        super().__init__(n_var=8,
                         n_obj=2,   #<------------
                         n_constr=0,
                         xl=np.array([0.5,2.5,0.,0.,0.,2.,2.,2.]),
                         xu=np.array([1.0,5.0,4.,4.,4.,10.,10.,10.]))

    def _evaluate(self, x, out, *args, **kwargs):


        f1 = 1.-res.get_score(x)[0] # efficiency
        f2 = res.get_volume() # volume
        #f3 = res.get_score(x)[1] #resolution

        out["F"] = [f1, f2]#, f3]

# %% [markdown]
# ### Creation of Problem and choice of optimization algorithm.
#
#
# * We will use NSGA-II, as explained in the lectures. You can decide the population size and the number of offsprings, based on what we discussed.
#
#
# * Pymoo offers different algorithms that can be used which are highly customizable and can be easily extended.
# https://pymoo.org/algorithms/index.html
#
#
# * Before dealing with a problem, it's useful to compare with a list of test problems reported in https://pymoo.org/problems/index.html, where different scenarios in terms of Variables, Objectives, Constraints are described.

# %%
problem = MyProblem()


algorithm = NSGA2(pop_size=100,n_offsprings=20) #n_offsprings=10

res = minimize(problem,
               algorithm,
               ("n_gen", 50),
               verbose=True,
               seed=1,
               save_history=True)
# Out:
# ==========================================================
# n_gen  |  n_eval  | n_nds  |      eps      |   indicator
# ==========================================================
#      1 |      100 |     16 |             - |             -
#      2 |      120 |     16 |  0.0091943315 |             f
#      3 |      140 |     18 |  0.0096463023 |         nadir
#      4 |      160 |     20 |  0.0852941176 |         ideal
#      5 |      180 |     22 |  0.0030228092 |             f
#      6 |      200 |     25 |  0.0072161126 |             f
#      7 |      220 |     29 |  0.0059171598 |         nadir
#      8 |      240 |     31 |  0.0075660660 |             f
#      9 |      260 |     38 |  0.0827679783 |         nadir
#     10 |      280 |     37 |  0.0014740566 |             f
#     11 |      300 |     35 |  0.0048721196 |             f
#     12 |      320 |     35 |  0.0037407966 |             f
#     13 |      340 |     36 |  0.0008817831 |             f
#     14 |      360 |     37 |  0.0055620839 |             f
#     15 |      380 |     34 |  0.0040540541 |         ideal
#     16 |      400 |     34 |  0.0028855124 |             f
#     17 |      420 |     34 |  0.0026333306 |             f
#     18 |      440 |     37 |  0.0028253503 |             f
#     19 |      460 |     35 |  0.0017897401 |             f
#     20 |      480 |     34 |  0.0024091023 |             f
#     21 |      500 |     33 |  0.0049416189 |             f
#     22 |      520 |     33 |  0.0050327757 |             f
#     23 |      540 |     35 |  0.0023295549 |             f
#     24 |      560 |     35 |  0.0053763441 |         ideal
#     25 |      580 |     37 |  0.0751445087 |         nadir
#     26 |      600 |     37 |  0.0042142114 |         ideal
#     27 |      620 |     39 |  0.0016179258 |             f
#     28 |      640 |     37 |  0.0023645770 |             f
#     29 |      660 |     33 |  0.0038683143 |             f
#     30 |      680 |     35 |  0.0006176617 |             f
#     31 |      700 |     34 |  0.0008468165 |             f
#     32 |      720 |     36 |  0.0026771572 |             f
#     33 |      740 |     40 |  0.0017839831 |             f
#     34 |      760 |     42 |  0.0025160583 |             f
#     35 |      780 |     38 |  0.0204978038 |         nadir
#     36 |      800 |     36 |  0.0058224163 |         ideal
#     37 |      820 |     37 |  0.0016432622 |             f
#     38 |      840 |     41 |  0.0049386743 |             f
#     39 |      860 |     40 |  0.0000727802 |             f
#     40 |      880 |     39 |  0.0021962121 |             f
#     41 |      900 |     42 |  0.0030205773 |             f
#     42 |      920 |     43 |  0.0016717997 |             f
#     43 |      940 |     44 |  0.0031043880 |             f
#     44 |      960 |     44 |  0.0018034089 |             f
#     45 |      980 |     45 |  0.0028646012 |             f
#     46 |     1000 |     46 |  0.0006842657 |             f
#     47 |     1020 |     47 |  0.0011032916 |             f
#     48 |     1040 |     50 |  0.0033810708 |             f
#     49 |     1060 |     50 |  0.0000582242 |             f
#     50 |     1080 |     53 |  0.0011885416 |             f

# %% [markdown]
# ### Analysis of Results

# %%
import plotly.express as px

fig = px.scatter(res.F, x=0, y=1, labels={'0': 'Efficiency', '1': 'Volume'},
                    title="Efficiency vs Volume",
                    width=800, height=800)
fig.update_traces(marker=dict(size=8,
                              line=dict(width=1,
                                        color='DarkSlateGrey')),
                    selector=dict(mode='markers'))
fig.show()
# Out:
# <div>                            <div id="b638d0dd-002f-4986-9eca-499076fba519" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b638d0dd-002f-4986-9eca-499076fba519")) {                    Plotly.newPlot(                        "b638d0dd-002f-4986-9eca-499076fba519",                        [{"hovertemplate":"Efficiency=%{x}\u003cbr\u003eVolume=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle","line":{"color":"DarkSlateGrey","width":1},"size":8},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[0.738,0.09899999999999998,0.07599999999999996,0.32299999999999995,0.29500000000000004,0.527,0.399,0.45799999999999996,0.393,0.363,0.19299999999999995,0.7170000000000001,0.752,0.18200000000000005,0.07099999999999995,0.401,0.06499999999999995,0.45499999999999996,0.631,0.35,0.16300000000000003,0.471,0.13,0.7170000000000001,0.361,0.41300000000000003,0.258,0.20699999999999996,0.36,0.721,0.14200000000000002,0.6739999999999999,0.471,0.505,0.5800000000000001,0.364,0.5469999999999999,0.21999999999999997,0.602,0.44599999999999995,0.41500000000000004,0.11199999999999999,0.20499999999999996,0.6699999999999999,0.07899999999999996,0.6579999999999999,0.645,0.33399999999999996,0.14900000000000002,0.20799999999999996,0.5780000000000001,0.648,0.16100000000000003],"xaxis":"x","y":[55.70272008545624,231.11417811832902,243.59099190966558,140.241208192748,148.12829556348362,82.07685985687286,106.98779307797913,94.9972663569704,107.89433781742379,111.60614380851916,179.31866195639438,59.95932088813703,53.81840055087914,187.2852540676264,243.6146735146521,103.98024116969101,280.1805403312882,97.63489926461746,71.43080358183994,117.03823176400981,191.52809714977312,92.38623242887088,226.4731243654525,59.95932088813703,116.75686742899482,103.26327486290266,149.36845680169247,166.3174349639388,116.90325600471796,57.53226869612317,223.55556201813556,60.72850584590779,92.38623242887088,84.89641032723343,78.22051482192059,111.18879286341661,81.86478379628235,160.86471060639113,73.27389381726708,97.64047365381687,99.38721593203984,230.05067674530304,173.76799759668899,63.924742995692405,235.75613565934077,69.24838034860285,69.46348274803321,123.42756307927324,222.6296871728739,163.70342221905037,81.77599276837152,69.40800192787145,207.78770802801566],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222 ...

# %%
import plotly.express as px

fig = px.scatter_3d(x = res.F[:, 0], y = res.F[:, 1], z = res.F[:, 2], labels={
                     "x": "InEfficiency",
                     "y": "Volume",
                     "z": "Resolution"
                 },width = 800, height = 800, title = "Final Call feasible solutions")
fig.update_traces(marker=dict(size=8,
                              line=dict(width=2,
                                        color='DarkSlateGrey')),
                  selector=dict(mode='markers'))
fig.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[18], line 3
#       1 import plotly.express as px
# ----> 3 fig = px.scatter_3d(x = res.F[:, 0], y = res.F[:, 1], z = res.F[:, 2], labels={
#       4                      "x": "InEfficiency",
#       5                      "y": "Volume",
#       6                      "z": "Resolution"
#       7                  },width = 800, height = 800, title = "Final Call feasible solutions")
#       8 fig.update_traces(marker=dict(size=8,
#       9                               line=dict(width=2,
#      10                                         color='DarkSlateGrey')),
#      11                   selector=dict(mode='markers'))
#      12 fig.show()
#
# IndexError: index 2 is out of bounds for axis 1 with size 2

# %%
# Making a animation of evolution
import pandas as pd

obj1 = []
obj2 = []
obj3 = []
calls = []
for r in res.history:

    objs = r.pop.get("F")
    obj1.extend(objs[:, 0])
    obj2.extend(objs[:, 1])
    obj3.extend(objs[:, 2])
    calls.extend([r.n_gen]*len(objs))
df = pd.DataFrame(data = {"InEfficiency": obj1, "Volume": obj2,
                          "Resolution": obj3, "n_gen": calls})

obj_fig = px.scatter_3d(df, x="InEfficiency", y="Volume", z = "Resolution",
                        animation_frame="n_gen", color="n_gen",
                        range_x=[0., 0.6], range_y=[0. , 400.], range_z=[0., 0.6],
                        hover_data = df.columns,
                        width = 800, height = 800)
obj_fig.update(layout_coloraxis_showscale=False)
obj_fig.layout.updatemenus[0].buttons[0].args[1]["frame"]["duration"] = 10
obj_fig.update_layout(transition = {'duration': 0.001})
obj_fig.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[19], line 13
#      11     obj1.extend(objs[:, 0])
#      12     obj2.extend(objs[:, 1])
# ---> 13     obj3.extend(objs[:, 2])
#      14     calls.extend([r.n_gen]*len(objs))
#      15 df = pd.DataFrame(data = {"InEfficiency": obj1, "Volume": obj2,
#      16                           "Resolution": obj3, "n_gen": calls})
#
# IndexError: index 2 is out of bounds for axis 1 with size 2

# %%
import matplotlib.pyplot as plt
import warnings; warnings.simplefilter('ignore')
fig = plt.figure(figsize = (12, 10))
ax = fig.add_subplot(projection='3d')
ax.scatter(res.F[:, 0], res.F[:, 1], res.F[:, 2], marker = "o", s = 55)

ax.set_xlabel('Ineff', fontsize = 15)
ax.set_ylabel('Vol', fontsize = 15)
ax.set_zlabel('Res', fontsize = 15)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[20], line 5
#       3 fig = plt.figure(figsize = (12, 10))
#       4 ax = fig.add_subplot(projection='3d')
# ----> 5 ax.scatter(res.F[:, 0], res.F[:, 1], res.F[:, 2], marker = "o", s = 55)
#       7 ax.set_xlabel('Ineff', fontsize = 15)
#       8 ax.set_ylabel('Vol', fontsize = 15)
#
# IndexError: index 2 is out of bounds for axis 1 with size 2

# %% [markdown]
# ---
#
# ### Exercise 3
#
#
# - Determine the Pareto set from the 3D front and choose an optimal point
#
# - Plot the optimal configuration of the tracker corresponding to that point
#
# - Do analysis of convergence
#
# - Visualize the point with a radar or petal diagram, following https://pymoo.org/visualization/index.html
